# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\python 3.9.1\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\python 3.9.1\lib\site-packages (from seaborn) (1.21.6)
# Requirement already satisfied: pandas>=1.2 in c:\python 3.9.1\lib\site-packages (from seaborn) (1.2.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\python 3.9.1\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python 3.9.1\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\python 3.9.1\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python 3.9.1\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python 3.9.1\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\python 3.9.1\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\python 3.9.1\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python 3.9.1\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python 3.9.1\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\python 3.9.1\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (5.12.0)
# Requirement already satisfied: pytz>=2017.3 in c:\python 3.9.1\lib\site-packages (from pandas>=1.2->seaborn) (2022.7.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\python 3.9.1\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\python 3.9.1\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
import os
from datetime import datetime

# %%
dataset = pd.read_csv('wind_dataset.csv')
dataset
# Out:
#               Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0      01 01 2018 00:00           380.047791          5.311336
# 1      01 01 2018 00:10           453.769196          5.672167
# 2      01 01 2018 00:20           306.376587          5.216037
# 3      01 01 2018 00:30           419.645904          5.659674
# 4      01 01 2018 00:40           380.650696          5.577941
# ...                 ...                  ...               ...
# 50525  31 12 2018 23:10          2963.980957         11.404030
# 50526  31 12 2018 23:20          1684.353027          7.332648
# 50527  31 12 2018 23:30          2201.106934          8.435358
# 50528  31 12 2018 23:40          2515.694092          9.421366
# 50529  31 12 2018 23:50          2820.466064          9.979332
#
#        Theoretical_Power_Curve (KWh)  Wind Direction
# 0                         416.328908      259.994904
# 1                         519.917511      268.641113
# 2                         390.900016      272.564789
# 3                         516.127569      271.258087
# 4                         491.702972      265.674286
# ...                              ...             ...
# 50525                    3397.190793       80.502724
# 50526                    1173.055771       84.062599
# 50527                    1788.284755       84.742500
# 50528                    2418.382503       84.297913
# 50529                    2779.184096       82.274620
#
# [50530 rows x 5 columns]

# %%
dataset.rename(columns = {'LV ActivePower (kW)':'ActivePower(kW)',
                       "Wind Speed (m/s)":"WindSpeed(m/s)",
                       "Wind Direction":"WindDirection","Theoretical_Power_Curve (KWh)":"TheoreticalPowerCurve(KWh)"},
            inplace = True)
dataset.head()
# Out:
#           Date/Time  ActivePower(kW)  WindSpeed(m/s)  \
# 0  01 01 2018 00:00       380.047791        5.311336
# 1  01 01 2018 00:10       453.769196        5.672167
# 2  01 01 2018 00:20       306.376587        5.216037
# 3  01 01 2018 00:30       419.645904        5.659674
# 4  01 01 2018 00:40       380.650696        5.577941
#
#    TheoreticalPowerCurve(KWh)  WindDirection
# 0                  416.328908     259.994904
# 1                  519.917511     268.641113
# 2                  390.900016     272.564789
# 3                  516.127569     271.258087
# 4                  491.702972     265.674286

# %%
dataset['Date/Time'] = pd.to_datetime(dataset['Date/Time'],format='%d %m %Y %H:%M')
dataset['year'] = dataset['Date/Time'].dt.year 
dataset['month'] = dataset['Date/Time'].dt.month 
dataset['day'] = dataset['Date/Time'].dt.day
dataset['Hour'] = dataset['Date/Time'].dt.hour 
dataset['minute'] = dataset['Date/Time'].dt.minute
dataset.head()
# Out:
#             Date/Time  ActivePower(kW)  WindSpeed(m/s)  \
# 0 2018-01-01 00:00:00       380.047791        5.311336
# 1 2018-01-01 00:10:00       453.769196        5.672167
# 2 2018-01-01 00:20:00       306.376587        5.216037
# 3 2018-01-01 00:30:00       419.645904        5.659674
# 4 2018-01-01 00:40:00       380.650696        5.577941
#
#    TheoreticalPowerCurve(KWh)  WindDirection  year  month  day  Hour  minute
# 0                  416.328908     259.994904  2018      1    1     0       0
# 1                  519.917511     268.641113  2018      1    1     0      10
# 2                  390.900016     272.564789  2018      1    1     0      20
# 3                  516.127569     271.258087  2018      1    1     0      30
# 4                  491.702972     265.674286  2018      1    1     0      40

# %%
def mean_speed(x):
    x = round(x,2)
    a = x//1
    a,b = a+0.25,a+0.75
    if x < a:
        x = a - 0.25
    else:
        x = b -0.25
    return x

# %%
dataset['meanSpeed']=dataset['WindSpeed(m/s)'].apply(mean_speed)
dataset.head()
# Out:
#             Date/Time  ActivePower(kW)  WindSpeed(m/s)  \
# 0 2018-01-01 00:00:00       380.047791        5.311336
# 1 2018-01-01 00:10:00       453.769196        5.672167
# 2 2018-01-01 00:20:00       306.376587        5.216037
# 3 2018-01-01 00:30:00       419.645904        5.659674
# 4 2018-01-01 00:40:00       380.650696        5.577941
#
#    TheoreticalPowerCurve(KWh)  WindDirection  year  month  day  Hour  minute  \
# 0                  416.328908     259.994904  2018      1    1     0       0
# 1                  519.917511     268.641113  2018      1    1     0      10
# 2                  390.900016     272.564789  2018      1    1     0      20
# 3                  516.127569     271.258087  2018      1    1     0      30
# 4                  491.702972     265.674286  2018      1    1     0      40
#
#    meanSpeed
# 0        5.5
# 1        5.5
# 2        5.0
# 3        5.5
# 4        5.5

# %%
def mean_direction(x):
    list=[]
    i=15
    while i<=375:
        list.append(i)
        i+=30
        
    for i in list:
        if x < i:
            x=i-15
            if x==360:
                return 0
            else:
                return x

# %%
dataset["meanDirection"]=dataset["WindDirection"].apply(mean_direction)
dataset.head()
# Out:
#             Date/Time  ActivePower(kW)  WindSpeed(m/s)  \
# 0 2018-01-01 00:00:00       380.047791        5.311336
# 1 2018-01-01 00:10:00       453.769196        5.672167
# 2 2018-01-01 00:20:00       306.376587        5.216037
# 3 2018-01-01 00:30:00       419.645904        5.659674
# 4 2018-01-01 00:40:00       380.650696        5.577941
#
#    TheoreticalPowerCurve(KWh)  WindDirection  year  month  day  Hour  minute  \
# 0                  416.328908     259.994904  2018      1    1     0       0
# 1                  519.917511     268.641113  2018      1    1     0      10
# 2                  390.900016     272.564789  2018      1    1     0      20
# 3                  516.127569     271.258087  2018      1    1     0      30
# 4                  491.702972     265.674286  2018      1    1     0      40
#
#    meanSpeed  meanDirection
# 0        5.5            270
# 1        5.5            270
# 2        5.0            270
# 3        5.5            270
# 4        5.5            270

# %%
directiondict = {0:"N", 30:"NNE", 60:"NEE", 90:"E", 120:"SEE", 150:"SSE", 180:"S", 210:"SSW", 240:"SWW", 270:"W", 300:"NWW", 330:"NNW"}

def wind_direction(x):
  for x in directiondict:
    return directiondict[x]

# %%
dataset['windCDirection']=dataset['WindDirection'].apply(wind_direction)
dataset.head(100)
# Out:
#              Date/Time  ActivePower(kW)  WindSpeed(m/s)  \
# 0  2018-01-01 00:00:00       380.047791        5.311336
# 1  2018-01-01 00:10:00       453.769196        5.672167
# 2  2018-01-01 00:20:00       306.376587        5.216037
# 3  2018-01-01 00:30:00       419.645904        5.659674
# 4  2018-01-01 00:40:00       380.650696        5.577941
# ..                 ...              ...             ...
# 95 2018-01-01 15:50:00      2820.512939       10.772420
# 96 2018-01-01 16:00:00      2812.279053       10.647520
# 97 2018-01-01 16:10:00      2530.447021        9.982661
# 98 2018-01-01 16:20:00      2399.121094        9.874386
# 99 2018-01-01 16:30:00      2335.587891        9.785480
#
#     TheoreticalPowerCurve(KWh)  WindDirection  year  month  day  Hour  minute  \
# 0                   416.328908     259.994904  2018      1    1     0       0
# 1                   519.917511     268.641113  2018      1    1     0      10
# 2                   390.900016     272.564789  2018      1    1     0      20
# 3                   516.127569     271.258087  2018      1    1     0      30
# 4                   491.702972     265.674286  2018      1    1     0      40
# ..                         ...            ...   ...    ...  ...   ...     ...
# 95                 3186.029883     225.276398  2018      1    1    15      50
# 96                 3133.259224     224.680603  2018      1    1    16       0
# 97                 2781.274041     225.519501  2018      1    1    16      10
# 98                 2711.492458     227.273804  2018      1    1    16      20
# 99                 2651.341009     229.255493  2018      1    1    16      30
#
#     meanSpeed  meanDirection windCDirection
# 0         5.5            270              N
# 1         5.5            270              N
# 2         5.0            270              N
# 3         5.5            270              N
# 4         5.5            270              N
# ..        ...            ...            ...
# 95       10.5            240              N
# 96       10.5            210              N
# 97        9.5            240              N
# 98        9.5            240              N
# 99        9.5            240              N
#
# [100 rows x 13 columns]

# %%
dataset['windCDirection']=dataset['WindDirection'].apply(wind_direction)
dataset.head()
# Out:
#             Date/Time  ActivePower(kW)  WindSpeed(m/s)  \
# 0 2018-01-01 00:00:00       380.047791        5.311336
# 1 2018-01-01 00:10:00       453.769196        5.672167
# 2 2018-01-01 00:20:00       306.376587        5.216037
# 3 2018-01-01 00:30:00       419.645904        5.659674
# 4 2018-01-01 00:40:00       380.650696        5.577941
#
#    TheoreticalPowerCurve(KWh)  WindDirection  year  month  day  Hour  minute  \
# 0                  416.328908     259.994904  2018      1    1     0       0
# 1                  519.917511     268.641113  2018      1    1     0      10
# 2                  390.900016     272.564789  2018      1    1     0      20
# 3                  516.127569     271.258087  2018      1    1     0      30
# 4                  491.702972     265.674286  2018      1    1     0      40
#
#    meanSpeed  meanDirection windCDirection
# 0        5.5            270              N
# 1        5.5            270              N
# 2        5.0            270              N
# 3        5.5            270              N
# 4        5.5            270              N

# %%
X = dataset[['WindDirection', 'month', 'day', 'Hour', 'meanSpeed']]
X
# Out:
#        WindDirection  month  day  Hour  meanSpeed
# 0         259.994904      1    1     0        5.5
# 1         268.641113      1    1     0        5.5
# 2         272.564789      1    1     0        5.0
# 3         271.258087      1    1     0        5.5
# 4         265.674286      1    1     0        5.5
# ...              ...    ...  ...   ...        ...
# 50525      80.502724     12   31    23       11.5
# 50526      84.062599     12   31    23        7.5
# 50527      84.742500     12   31    23        8.5
# 50528      84.297913     12   31    23        9.5
# 50529      82.274620     12   31    23        9.5
#
# [50530 rows x 5 columns]

# %%
Y = dataset['ActivePower(kW)']
Y
# Out:
# 0         380.047791
# 1         453.769196
# 2         306.376587
# 3         419.645904
# 4         380.650696
#             ...
# 50525    2963.980957
# 50526    1684.353027
# 50527    2201.106934
# 50528    2515.694092
# 50529    2820.466064
# Name: ActivePower(kW), Length: 50530, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error , r2_score
import joblib

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.02, random_state = 42)

# %%
lasso = Lasso(alpha=0.01)
model = lasso.fit(X_train, Y_train)

# %%
pred_train_lasso= lasso.predict(X_train)

print("Training RMSE and R2 score:")
print(np.sqrt(mean_squared_error(Y_train,pred_train_lasso)))
print(r2_score(Y_train, pred_train_lasso))

pred_test_lasso= lasso.predict(X_test)
print("Testing RMSE and R2 score:")
print(np.sqrt(mean_squared_error(Y_test,pred_test_lasso))) 
print(r2_score(Y_test, pred_test_lasso))
# Out:
# Training RMSE and R2 score:
# 535.0570996467623
# 0.8338015833105206
# Testing RMSE and R2 score:
# 535.7591488824197
# 0.8331305745239681

# %%
print('Prediction of wind power for these input parameters: ', model.predict([[254.65,6,1,23,5.7]]))
# Out:
# Prediction of wind power for these input parameters:  [888.64221297]

# %%
### Create a Pickle file using serialization 
import pickle
pickle_out = open("trained_model.pkl","wb")
pickle.dump(model, pickle_out)
pickle_out.close()
